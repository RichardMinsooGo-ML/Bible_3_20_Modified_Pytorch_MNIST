# %%
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_20_Modified_Pytorch_MNIST.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 122 (delta 13), reused 0 (delta 0), pack-reused 96
# Receiving objects: 100% (122/122), 33.51 KiB | 16.75 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_20_Modified_Pytorch_MNIST
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
! python train.py --num_epochs 10 --batch_size 100
# Out:
# {'pretrained_path': 'checkpoints/Mnist.pth', 'save_path': 'checkpoints/Mnist.pth', 'working_dir': './', 'input_size': 784, 'hidden_size': 200, 'output_dim': 10, 'num_epochs': 10, 'batch_size': 100, 'learning_rate': 0.0005, 'gradient_accumulations': 2, 'ckpt_dir': './checkpoints', 'logs_dir': './logs'}
# cpu
# ...
# 100% 9912422/9912422 [00:00<00:00, 61790460.35it/s]
# Extracting /root/.torch/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /root/.torch/mnist/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 108739402.00it/s]
# Extracting /root/.torch/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /root/.torch/mnist/MNIST/raw
#
# ...
# 100% 1648877/1648877 [00:00<00:00, 86913630.38it/s]
# Extracting /root/.torch/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/.torch/mnist/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 3143651.61it/s]
# Extracting /root/.torch/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.torch/mnist/MNIST/raw
#
# checkpoints/Mnist.pth
# 600
# ...
